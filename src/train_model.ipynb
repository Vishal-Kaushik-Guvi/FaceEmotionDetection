# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Dense, Dropout, Flatten, BatchNormalization
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "../dataset/train"
test_dir = "../dataset/test"

IMG_SIZE = 48
BATCH_SIZE = 64
EPOCHS = 30

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(
    rescale=1./255
)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

num_classes = train_generator.num_classes
print("Number of emotion classes:", num_classes)
# Out:
# Found 7178 images belonging to 7 classes.
# Found 1896 images belonging to 7 classes.
# Number of emotion classes: 7

# %%
model = Sequential()

# Block 1
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(48,48,1)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Block 2
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Block 3
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Fully Connected Layers
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# D:\anaconda3\envs\cv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 46, 46, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 46, 46, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 23, 23, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 23, 23, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 21, 21, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 21, 21, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │             903 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 356,743 (1.36 MB)
#  Trainable params: 356,295 (1.36 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=test_generator
)
# Out:
# Epoch 1/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 23s 169ms/step - accuracy: 0.1850 - loss: 2.5767 - val_accuracy: 0.1899 - val_loss: 3.3175
# Epoch 2/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 18s 159ms/step - accuracy: 0.2062 - loss: 1.9449 - val_accuracy: 0.1899 - val_loss: 4.3946
# Epoch 3/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 167ms/step - accuracy: 0.2193 - loss: 1.8828 - val_accuracy: 0.1893 - val_loss: 4.0017
# Epoch 4/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.2292 - loss: 1.8656 - val_accuracy: 0.2031 - val_loss: 2.8601
# Epoch 5/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 168ms/step - accuracy: 0.2313 - loss: 1.8520 - val_accuracy: 0.2505 - val_loss: 2.1043
# Epoch 6/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 164ms/step - accuracy: 0.2379 - loss: 1.8359 - val_accuracy: 0.2780 - val_loss: 1.8312
# Epoch 7/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 167ms/step - accuracy: 0.2396 - loss: 1.8282 - val_accuracy: 0.2753 - val_loss: 1.7839
# Epoch 8/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 165ms/step - accuracy: 0.2435 - loss: 1.8101 - val_accuracy: 0.2732 - val_loss: 1.7690
# Epoch 9/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 166ms/step - accuracy: 0.2491 - loss: 1.8097 - val_accuracy: 0.3075 - val_loss: 1.7457
# Epoch 10/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 167ms/step - accuracy: 0.2541 - loss: 1.8003 - val_accuracy: 0.3054 - val_loss: 1.7407
# Epoch 11/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 165ms/step - accuracy: 0.2536 - loss: 1.7998 - val_accuracy: 0.3138 - val_loss: 1.7296
# Epoch 12/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.2616 - loss: 1.7856 - val_accuracy: 0.3228 - val_loss: 1.7178
# Epoch 13/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 165ms/step - accuracy: 0.2701 - loss: 1.7809 - val_accuracy: 0.3318 - val_loss: 1.7048
# Epoch 14/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 168ms/step - accuracy: 0.2657 - loss: 1.7851 - val_accuracy: 0.3391 - val_loss: 1.6973
# Epoch 15/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 168ms/step - accuracy: 0.2721 - loss: 1.7733 - val_accuracy: 0.3397 - val_loss: 1.6893
# Epoch 16/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 169ms/step - accuracy: 0.2823 - loss: 1.7680 - val_accuracy: 0.3312 - val_loss: 1.6861
# Epoch 17/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.2829 - loss: 1.7668 - val_accuracy: 0.3333 - val_loss: 1.6774
# Epoch 18/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 22s 192ms/step - accuracy: 0.2770 - loss: 1.7512 - val_accuracy: 0.3391 - val_loss: 1.6911
# Epoch 19/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 25s 216ms/step - accuracy: 0.2855 - loss: 1.7497 - val_accuracy: 0.3528 - val_loss: 1.6668
# Epoch 20/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 20s 173ms/step - accuracy: 0.2927 - loss: 1.7483 - val_accuracy: 0.3534 - val_loss: 1.6545
# Epoch 21/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 23s 202ms/step - accuracy: 0.2967 - loss: 1.7363 - val_accuracy: 0.3507 - val_loss: 1.6646
# Epoch 22/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.3005 - loss: 1.7350 - val_accuracy: 0.3486 - val_loss: 1.6496
# Epoch 23/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 20s 177ms/step - accuracy: 0.3013 - loss: 1.7283 - val_accuracy: 0.3539 - val_loss: 1.6417
# Epoch 24/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 24s 214ms/step - accuracy: 0.3062 - loss: 1.7255 - val_accuracy: 0.3418 - val_loss: 1.6702
# Epoch 25/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 23s 199ms/step - accuracy: 0.3080 - loss: 1.7136 - val_accuracy: 0.3486 - val_loss: 1.6394
# Epoch 26/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 23s 200ms/step - accuracy: 0.3167 - loss: 1.7088 - val_accuracy: 0.3407 - val_loss: 1.6304
# Epoch 27/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.3129 - loss: 1.7097 - val_accuracy: 0.3528 - val_loss: 1.6176
# Epoch 28/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 20s 173ms/step - accuracy: 0.3218 - loss: 1.7041 - val_accuracy: 0.3407 - val_loss: 1.6479
# Epoch 29/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 21s 183ms/step - accuracy: 0.3139 - loss: 1.6993 - val_accuracy: 0.3455 - val_loss: 1.6439
# Epoch 30/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.3250 - loss: 1.6877 - val_accuracy: 0.3528 - val_loss: 1.6445

# %%
model.save("../models/emotion_model.h5")
print("Model saved successfully!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!
